# %%
import graphlab

# %%
user = graphlab.SFrame('fresh_comp_offline/tianchi_fresh_comp_train_user.csv')
# Out:
# This non-commercial license of GraphLab Create for academic use is assigned to y_xwang@163.com and will expire on March 13, 2018.
# [INFO] graphlab.cython.cy_server: GraphLab Create v2.1 started. Logging: /tmp/graphlab_server_1489637535.log
# Finished parsing file /home/quoniam/version-control/happy-machine-learning/Alibaba_ML/newer_race/fresh_comp_offline/tianchi_fresh_comp_train_user.csv
# Parsing completed. Parsed 100 lines in 6.18169 secs.
# ------------------------------------------------------
# Inferred types from first 100 line(s) of file as
# column_type_hints=[int,int,int,str,int,str]
# If parsing fails due to incorrect types, you can correct
# the inferred type list above and pass it to read_csv in
# the column_type_hints argument
# ------------------------------------------------------
# Read 1164737 lines. Lines per second: 154778
# Read 3492805 lines. Lines per second: 220330
# Read 4682970 lines. Lines per second: 187669
# Read 5876562 lines. Lines per second: 147741
# Read 7069664 lines. Lines per second: 151215
# Read 8256631 lines. Lines per second: 153382
# Read 9415632 lines. Lines per second: 157932
# Read 11744698 lines. Lines per second: 177262
# Read 12933042 lines. Lines per second: 172128
# Read 15313289 lines. Lines per second: 183072
# Read 17642564 lines. Lines per second: 189886
# Read 19994751 lines. Lines per second: 200866
# Read 22373099 lines. Lines per second: 211105
# Finished parsing file /home/quoniam/version-control/happy-machine-learning/Alibaba_ML/newer_race/fresh_comp_offline/tianchi_fresh_comp_train_user.csv
# Parsing completed. Parsed 23291027 lines in 106.929 secs.

# %%
item = graphlab.SFrame('fresh_comp_offline/tianchi_fresh_comp_train_item.csv')
# Out:
# Finished parsing file /home/quoniam/version-control/happy-machine-learning/Alibaba_ML/newer_race/fresh_comp_offline/tianchi_fresh_comp_train_item.csv
# Parsing completed. Parsed 100 lines in 1.17576 secs.
# ------------------------------------------------------
# Inferred types from first 100 line(s) of file as
# column_type_hints=[int,str,int]
# If parsing fails due to incorrect types, you can correct
# the inferred type list above and pass it to read_csv in
# the column_type_hints argument
# ------------------------------------------------------
# Finished parsing file /home/quoniam/version-control/happy-machine-learning/Alibaba_ML/newer_race/fresh_comp_offline/tianchi_fresh_comp_train_item.csv
# Parsing completed. Parsed 620918 lines in 0.947133 secs.

# %%
item.head()
# Out:
# Columns:
# 	item_id	int
# 	item_geohash	str
# 	item_category	int
#
# Rows: 10
#
# Data:
# +-----------+--------------+---------------+
# |  item_id  | item_geohash | item_category |
# +-----------+--------------+---------------+
# | 100002303 |              |      3368     |
# | 100003592 |              |      7995     |
# | 100006838 |              |     12630     |
# | 100008089 |              |      7791     |
# | 100012750 |              |      9614     |
# | 100014072 |              |      1032     |
# | 100014463 |              |      9023     |
# | 100019387 |              |      3064     |
# | 100023812 |              |      6700     |
# |  10003007 |              |      5827     |
# +-----------+--------------+---------------+
# [10 rows x 3 columns]

# %%
graphlab.canvas.set_target('ipynb')

user['user_id'].show(view='Categorical')

# %%
user = user[user['user_id'] == 3279691]

# %%
user['sentiment'] = user['behavior_type'] >= 3

# %%
user.head()
# Out:
# Columns:
# 	user_id	int
# 	item_id	int
# 	behavior_type	int
# 	user_geohash	str
# 	item_category	int
# 	time	str
# 	sentiment	int
#
# Rows: 10
#
# Data:
# +---------+-----------+---------------+--------------+---------------+
# | user_id |  item_id  | behavior_type | user_geohash | item_category |
# +---------+-----------+---------------+--------------+---------------+
# | 3279691 |  55868859 |       1       |   95ihhcb    |      5894     |
# | 3279691 | 257897620 |       1       |   95ihhbd    |      2953     |
# | 3279691 |  34635028 |       1       |              |     11385     |
# | 3279691 | 209339273 |       1       |              |      5503     |
# | 3279691 | 129975472 |       1       |              |      5689     |
# | 3279691 |  62316341 |       1       |              |      6255     |
# | 3279691 | 369692912 |       3       |              |      5689     |
# | 3279691 |  35454054 |       1       |              |      6255     |
# | 3279691 | 219791855 |       1       |              |      5395     |
# | 3279691 | 290809061 |       1       |   95ihki5    |      6255     |
# +---------+-----------+---------------+--------------+---------------+
# +---------------+-----------+
# |      time     | sentiment |
# +---------------+-----------+
# | 2014-11-28 13 |     0     |
# | 2014-11-28 13 |     0     |
# | 2014-12-04 07 |     0     |
# | 2014-12-11 05 |     0     |
# | 2014-11-25 05 |     0     |
# | 2014-11-19 06 |     0     |
# | 2014-11-21 04 |     1     |
# | 2014-11-20 01 |     0     |
# | 2014-11-28 06 |     0     |
# | 2014-12-03 15 |     0     |
# +---------------+-----------+
# [10 rows x 7 columns]

# %%
train_data, test_data = user.random_split(.8, seed=0)

# %%
sentiment_model = graphlab.logistic_classifier.create(train_data, target='sentiment', features=['behavior_type'], validation_set=test_data)
# Out:
# Logistic regression:
# --------------------------------------------------------
# Number of examples          : 18810
# Number of classes           : 2
# Number of feature columns   : 1
# Number of unpacked features : 1
# Number of coefficients    : 2
# Starting Newton Method
# --------------------------------------------------------
# +-----------+----------+--------------+-------------------+---------------------+
# | Iteration | Passes   | Elapsed Time | Training-accuracy | Validation-accuracy |
# +-----------+----------+--------------+-------------------+---------------------+
# | 1         | 2        | 0.085404     | 1.000000          | 1.000000            |
# | 2         | 3        | 0.117975     | 1.000000          | 1.000000            |
# | 3         | 4        | 0.161632     | 1.000000          | 1.000000            |
# | 4         | 5        | 0.215551     | 1.000000          | 1.000000            |
# | 5         | 6        | 0.265546     | 1.000000          | 1.000000            |
# | 6         | 7        | 0.311145     | 1.000000          | 1.000000            |
# +-----------+----------+--------------+-------------------+---------------------+
# TERMINATED: Iteration limit reached.
# This model may not be optimal. To improve it, consider increasing `max_iterations`.

# %%
sentiment_model.evaluate(test_data, metric='roc_curve')
# Out:
# {'roc_curve': Columns:
#  	threshold	float
#  	fpr	float
#  	tpr	float
#  	p	int
#  	n	int
#
#  Rows: 100001
#
#  Data:
#  +-----------+-----------------+-----+-----+------+
#  | threshold |       fpr       | tpr |  p  |  n   |
#  +-----------+-----------------+-----+-----+------+
#  |    0.0    |       1.0       | 1.0 | 577 | 3977 |
#  |   1e-05   | 0.0842343474981 | 1.0 | 577 | 3977 |
#  |   2e-05   | 0.0842343474981 | 1.0 | 577 | 3977 |
#  |   3e-05   | 0.0842343474981 | 1.0 | 577 | 3977 |
#  |   4e-05   | 0.0842343474981 | 1.0 | 577 | 3977 |
#  |   5e-05   | 0.0842343474981 | 1.0 | 577 | 3977 |
#  |   6e-05   | 0.0842343474981 | 1.0 | 577 | 3977 |
#  |   7e-05   | 0.0842343474981 | 1.0 | 577 | 3977 |
#  |   8e-05   | 0.0842343474981 | 1.0 | 577 | 3977 |
#  |   9e-05   | 0.0842343474981 | 1.0 | 577 | 3977 |
#  +-----------+-----------------+-----+-----+------+
#  [100001 rows x 5 columns]
#  Note: Only the head of the SFrame is printed.
#  You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.}

# %%
sentiment_model.show(view='Evaluation')
